# %%
import pandas as pd

# %%
two_thousands_df = pd.read_csv("dataset-of-00s.csv")
two_thousands_df
# Out:
#                                                   track  \
# 0                                             Lucky Man
# 1                                        On The Hotline
# 2                                    Clouds Of Dementia
# 3                              Heavy Metal, Raise Hell!
# 4                                       I Got A Feelin'
# ...                                                 ...
# 5867                                        Summer Rain
# 5868                                              And I
# 5869  Mass in B minor BWV 232, Missa: Duetto - Chris...
# 5870                                               Loog
# 5871                               What The World Needs
#
#                      artist                                   uri  \
# 0         Montgomery Gentry  spotify:track:4GiXBCUF7H6YfNQsnBRIzl
# 1              Pretty Ricky  spotify:track:1zyqZONW985Cs4osz9wlsu
# 2                Candlemass  spotify:track:6cHZf7RbxXCKwEkgAZT4mY
# ...

# %%
two_thousand_tens_df = pd.read_csv("dataset-of-10s.csv")
two_thousand_tens_df
# Out:
#                                     track                          artist  \
# 0                             Wild Things                    Alessia Cara
# 1                               Surfboard                       Esquivel!
# 2                            Love Someone                    Lukas Graham
# 3     Music To My Ears (feat. Tory Lanez)                   Keys N Krates
# 4           Juju On That Beat (TZ Anthem)  Zay Hilfigerrr & Zayion McCall
# ...                                   ...                             ...
# 6393                        Lotus Flowers                           Yolta
# 6394                    Calling My Spirit                     Kodak Black
# 6395                        Teenage Dream                      Katy Perry
# 6396                       Stormy Weather                  Oscar Peterson
# 6397                                 Dust                     Hans Zimmer
#
#                                        uri  danceability  energy  key  \
# ...

# %%
sixties_df = pd.read_csv("dataset-of-60s.csv")
sixties_df
# Out:
#                                track                       artist  \
# 0              Jealous Kind Of Fella                Garland Green
# 1                      Initials B.B.             Serge Gainsbourg
# 2                       Melody Twist                  Lord Melody
# 3                      Mi Bomba Sonó                   Celia Cruz
# 4                        Uravu Solla                  P. Susheela
# ...                              ...                          ...
# 8637                 Le ire di Ursus           Giampiero Boneschi
# 8638                           A-B-C                John Zacherle
# 8639               Useless Landscape         Antônio Carlos Jobim
# 8640               Vendedor De Assaí                     Ary Lobo
# 8641  Mambo Simphony - Remasterizado  Orquesta Casino De La Playa
#
#                                        uri  danceability  energy  key  \
# 0     spotify:track:1dtKN6wwlolkM8XZy2y9C1         0.417  0.6200    3
# ...

# %%
seventies_df = pd.read_csv("dataset-of-70s.csv")
seventies_df
# Out:
#                               track                 artist  \
# 0                           Porque?        Reginaldo Rossi
# 1                         Free Jazz   Maria Teresa Luciani
# 2                 Reject of Society                  Crass
# 3                            Yeah !               The Jets
# 4                  Gotta Find A Way            The Moments
# ...                             ...                    ...
# 7761            Born with the Blues          Buster Benton
# 7762       Farther On Down The Road              Joe Simon
# 7763                     Sweetheart  Engelbert Humperdinck
# 7764  Until It's Time For You To Go           Neil Diamond
# 7765  Try Me, I Know We Can Make It           Donna Summer
#
#                                        uri  danceability  energy  key  \
# 0     spotify:track:28KC2wl7jDv6Ms1Uc0OMpm         0.669   0.547    1
# 1     spotify:track:0zagn8PNnM7pM8pz1gXOAD         0.291   0.300    1
# ...

# %%
eighties_df = pd.read_csv("dataset-of-80s.csv")
eighties_df
# Out:
#                                                   track             artist  \
# 0                                         Walking Blues   Big Joe Williams
# 1                                  Suddenly Last Summer         The Motels
# 2                                             Sanctuary         Béla Fleck
# 3                                        The Wild Rover         The Pogues
# 4                                  In The Driver's Seat     John Schneider
# ...                                                 ...                ...
# 6903  Bachke Rehna Re Baba - Pukar / Soundtrack Version      Kishore Kumar
# 6904                                  Tiempos Metálicos                 V8
# 6905                                                Joy  Teddy Pendergrass
# 6906                                I Wanna Be A Cowboy     Boys Don't Cry
# 6907                                    Hot In The City         Billy Idol
#
# ...

# %%
nineties_df = pd.read_csv("dataset-of-90s.csv")
nineties_df
# Out:
#                                                track           artist  \
# 0                                        Misty Roses  Astrud Gilberto
# 1                                         Never Ever       All Saints
# 2                                        Soul Sermon    Gregg Karukas
# 3                          Clarinet Marmalade - Live    Alton Purnell
# 4     До смерті і довше - Drum & Base and Rock Remix         Skryabin
# ...                                              ...              ...
# 5515                           (You're A) Go Nowhere     Reagan Youth
# 5516                              La Fiebre de Norma     La Castañeda
# 5517                                      Good Times    Edie Brickell
# 5518                                           Inane            KMFDM
# 5519              You Can Make History (Young Again)       Elton John
#
#                                        uri  danceability  energy  key  \
# ...

# %%
frames = [two_thousands_df, two_thousand_tens_df, sixties_df, seventies_df, eighties_df, nineties_df]
df = pd.concat(frames)
df
# Out:
#                                    track             artist  \
# 0                              Lucky Man  Montgomery Gentry
# 1                         On The Hotline       Pretty Ricky
# 2                     Clouds Of Dementia         Candlemass
# 3               Heavy Metal, Raise Hell!      Zwartketterij
# 4                        I Got A Feelin'   Billy Currington
# ...                                  ...                ...
# 5515               (You're A) Go Nowhere       Reagan Youth
# 5516                  La Fiebre de Norma       La Castañeda
# 5517                          Good Times      Edie Brickell
# 5518                               Inane              KMFDM
# 5519  You Can Make History (Young Again)         Elton John
#
#                                        uri  danceability  energy  key  \
# 0     spotify:track:4GiXBCUF7H6YfNQsnBRIzl         0.578   0.471    4
# 1     spotify:track:1zyqZONW985Cs4osz9wlsu         0.704   0.854   10
# ...

# %%
cleaned_df = df.drop(['key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'duration_ms', 'time_signature', 'chorus_hit', 'sections', 'target'], axis = 1)
cleaned_df
# Out:
#                                    track             artist  \
# 0                              Lucky Man  Montgomery Gentry
# 1                         On The Hotline       Pretty Ricky
# 2                     Clouds Of Dementia         Candlemass
# 3               Heavy Metal, Raise Hell!      Zwartketterij
# 4                        I Got A Feelin'   Billy Currington
# ...                                  ...                ...
# 5515               (You're A) Go Nowhere       Reagan Youth
# 5516                  La Fiebre de Norma       La Castañeda
# 5517                          Good Times      Edie Brickell
# 5518                               Inane              KMFDM
# 5519  You Can Make History (Young Again)         Elton John
#
#                                        uri  danceability  energy    tempo
# 0     spotify:track:4GiXBCUF7H6YfNQsnBRIzl         0.578   0.471  133.061
# 1     spotify:track:1zyqZONW985Cs4osz9wlsu         0.704   0.854   92.988
# ...

# %%
cleaned_df['track'].replace(['''Jumpin', Jumpin'''], 'Jumpin, Jumpin')
# Out:
# 0                                Lucky Man
# 1                           On The Hotline
# 2                       Clouds Of Dementia
# 3                 Heavy Metal, Raise Hell!
# 4                          I Got A Feelin'
#                        ...
# 5515                 (You're A) Go Nowhere
# 5516                    La Fiebre de Norma
# 5517                            Good Times
# 5518                                 Inane
# 5519    You Can Make History (Young Again)
# Name: track, Length: 41106, dtype: object

# %%
cleaned_df.to_csv('cleaned_spotify_data.csv', index=False)
